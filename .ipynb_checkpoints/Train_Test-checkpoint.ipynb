# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import keras
from sklearn import preprocessing, svm
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
academic = pd.read_csv("Stu_processed.csv")
money = pd.read_csv("Financial_processed.csv")

# %%
print(academic.shape)
# Out:
# (1789, 16)

# %%
academic.head()
# Out:
#          ID LtrGrade           Department  Grade  Term_GPA   Course  \
# 0  18000007       C+  Business Management  77.13      2.23  ECO 110
# 1  18000007        D      Integrated Core  63.00      2.23  INT 110
# 2  18000007       C+    General Education  76.00      2.23  WRI 100
# 3  18000007       B+    General Education  87.00      2.23  MTH 100
# 4  18000007       A-  Business Management  92.39      2.25  MGT 315
#
#                       Name  Age  Attendance  Gender  Latino  Race    ZIP  \
# 0           Microeconomics   23       88.89       2       1     5  92126
# 1       Critical Reasoning   23       50.00       2       1     5  92126
# 2    College Composition I   23       55.81       2       1     5  92126
# 3          College Algebra   23       60.00       2       1     5  92126
# 4  Organizational Behavior   23       59.18       2       1     5  92126
#
#          LAT        LNG  ProfID
# 0  32.908449 -117.14138      76
# 1  32.908449 -117.14138      29
# 2  32.908449 -117.14138      10
# 3  32.908449 -117.14138      57
# 4  32.908449 -117.14138      41

# %%
print(academic['Department'].value_counts())
# Out:
# General Education      513
# Business Management    357
# Integrated Core        312
# Kinesiology            208
# Natural Sciences       194
# Arts and Humanities    149
# Psychology              30
# Other                   26
# Name: Department, dtype: int64

# %%
academic = academic.assign(DeptCat=(academic['Department']).astype('category').cat.codes)
academic.sample(5)
# Out:
#               ID LtrGrade           Department  Grade  Term_GPA   Course  \
# 1088  2017000057       B+  Business Management  86.35      2.73  MGT 100
# 930   2017000011       B-     Natural Sciences  81.17      2.95  CHE 300
# 1672  2018000072        A      Integrated Core  94.22      2.98  INT 100
# 387   2016000032       B-          Kinesiology  82.00      2.43  KIN 100
# 1540  2018000027       C+    General Education  76.34      2.80  WRI 100
#
#                                 Name  Age  Attendance  Gender  Latino  Race  \
# 1088       Foundations of Management   22      100.00       2       1     1
# 930                   Biochemistry I   22       81.48       3       1     2
# 1672  Interdisciplinary Liberal Arts   18       91.11       3       1     3
# 387        Fundamentals of Nutrition   22       80.77       2       1     1
# 1540           College Composition I   19       90.91       2       1     1
#
#         ZIP        LAT         LNG  ProfID  DeptCat
# 1088  92069  33.170775 -117.158676       4        1
# 930   92029  33.082400 -117.127641      33        5
# 1672      0   0.000000    0.000000      25        3
# 387   92026  33.212444 -117.116098      40        4
# 1540  88201  33.643275 -104.396622      10        2

# %%
academic = academic.assign(ProfClassCount=(academic['ProfID']).astype('category').cat.codes)
academic.head()
# Out:
#          ID LtrGrade           Department  Grade  Term_GPA   Course  \
# 0  18000007       C+  Business Management  77.13      2.23  ECO 110
# 1  18000007        D      Integrated Core  63.00      2.23  INT 110
# 2  18000007       C+    General Education  76.00      2.23  WRI 100
# 3  18000007       B+    General Education  87.00      2.23  MTH 100
# 4  18000007       A-  Business Management  92.39      2.25  MGT 315
#
#                       Name  Age  Attendance  Gender  Latino  Race    ZIP  \
# 0           Microeconomics   23       88.89       2       1     5  92126
# 1       Critical Reasoning   23       50.00       2       1     5  92126
# 2    College Composition I   23       55.81       2       1     5  92126
# 3          College Algebra   23       60.00       2       1     5  92126
# 4  Organizational Behavior   23       59.18       2       1     5  92126
#
#          LAT        LNG  ProfID  DeptCat  ProfClassCount
# 0  32.908449 -117.14138      76        1              43
# 1  32.908449 -117.14138      29        3              17
# 2  32.908449 -117.14138      10        2               4
# 3  32.908449 -117.14138      57        2              31
# 4  32.908449 -117.14138      41        1              24

# %%
# Create the bins in which Data will be held
# Bins are 0, 60, 70, 80, 90, 100
bins = [0, 20, 50, 100]

# Create the names for the four bins
#group_names represent these values = ["0-10", "20-50", "50-100"]

group_names = [1, 2, 3]

# %%
academic['ProfCount'] = pd.cut(academic['ProfID'], bins, labels=group_names)
academic.head()
# Out:
#          ID LtrGrade           Department  Grade  Term_GPA   Course  \
# 0  18000007       C+  Business Management  77.13      2.23  ECO 110
# 1  18000007        D      Integrated Core  63.00      2.23  INT 110
# 2  18000007       C+    General Education  76.00      2.23  WRI 100
# 3  18000007       B+    General Education  87.00      2.23  MTH 100
# 4  18000007       A-  Business Management  92.39      2.25  MGT 315
#
#                       Name  Age  Attendance  Gender  Latino  Race    ZIP  \
# 0           Microeconomics   23       88.89       2       1     5  92126
# 1       Critical Reasoning   23       50.00       2       1     5  92126
# 2    College Composition I   23       55.81       2       1     5  92126
# 3          College Algebra   23       60.00       2       1     5  92126
# 4  Organizational Behavior   23       59.18       2       1     5  92126
#
#          LAT        LNG  ProfID  DeptCat  ProfClassCount ProfCount
# 0  32.908449 -117.14138      76        1              43         3
# 1  32.908449 -117.14138      29        3              17         2
# 2  32.908449 -117.14138      10        2               4         1
# 3  32.908449 -117.14138      57        2              31         3
# 4  32.908449 -117.14138      41        1              24         2

# %%
#print(academic['ProfCount'].value_counts())

# %%
#print(academic['Age'].value_counts())

# %%
#print(academic['Attendance'].value_counts())

# %%
academic['ProfCount'].value_counts()
# Out:
# 2    714
# 3    646
# 1    420
# Name: ProfCount, dtype: int64

# %%
# Create the bins in which Data will be held
# Bins are 0, 60, 70, 80, 90, 100
bins = [16, 19, 21, 100]

# Create the names for the four bins
#group_names represent these ranges= ["17-19", "20-21", "Over 21"]
group_names = [1, 2, 3]

# %%
academic['AgeRange'] = pd.cut(academic['Age'], bins, labels=group_names)
academic.head()
# Out:
#          ID LtrGrade           Department  Grade  Term_GPA   Course  \
# 0  18000007       C+  Business Management  77.13      2.23  ECO 110
# 1  18000007        D      Integrated Core  63.00      2.23  INT 110
# 2  18000007       C+    General Education  76.00      2.23  WRI 100
# 3  18000007       B+    General Education  87.00      2.23  MTH 100
# 4  18000007       A-  Business Management  92.39      2.25  MGT 315
#
#                       Name  Age  Attendance  Gender  Latino  Race    ZIP  \
# 0           Microeconomics   23       88.89       2       1     5  92126
# 1       Critical Reasoning   23       50.00       2       1     5  92126
# 2    College Composition I   23       55.81       2       1     5  92126
# 3          College Algebra   23       60.00       2       1     5  92126
# 4  Organizational Behavior   23       59.18       2       1     5  92126
#
#          LAT        LNG  ProfID  DeptCat  ProfClassCount ProfCount AgeRange
# 0  32.908449 -117.14138      76        1              43         3        3
# 1  32.908449 -117.14138      29        3              17         2        3
# 2  32.908449 -117.14138      10        2               4         1        3
# 3  32.908449 -117.14138      57        2              31         3        3
# 4  32.908449 -117.14138      41        1              24         2        3

# %%
# Create the bins in which Data will be held
# Bins are 0, 60, 70, 80, 90, 100
bins = [0, 70, 80, 90, 100]

# Create the names for the four bins
#group_names represent these ranges = ["0-70", "70-80", "80-90", "90-100"]
group_names=[1, 2, 3, 4]

# %%
academic['AttendanceRange'] = pd.cut(academic['Attendance'], bins, labels=group_names)
academic.head()
# Out:
#          ID LtrGrade           Department  Grade  Term_GPA   Course  \
# 0  18000007       C+  Business Management  77.13      2.23  ECO 110
# 1  18000007        D      Integrated Core  63.00      2.23  INT 110
# 2  18000007       C+    General Education  76.00      2.23  WRI 100
# 3  18000007       B+    General Education  87.00      2.23  MTH 100
# 4  18000007       A-  Business Management  92.39      2.25  MGT 315
#
#                       Name  Age  Attendance  Gender  ...  Race    ZIP  \
# 0           Microeconomics   23       88.89       2  ...     5  92126
# 1       Critical Reasoning   23       50.00       2  ...     5  92126
# 2    College Composition I   23       55.81       2  ...     5  92126
# 3          College Algebra   23       60.00       2  ...     5  92126
# 4  Organizational Behavior   23       59.18       2  ...     5  92126
#
#          LAT        LNG  ProfID  DeptCat  ProfClassCount  ProfCount AgeRange  \
# 0  32.908449 -117.14138      76        1              43          3        3
# 1  32.908449 -117.14138      29        3              17          2        3
# 2  32.908449 -117.14138      10        2               4          1        3
# 3  32.908449 -117.14138      57        2              31          3        3
# 4  32.908449 -117.14138      41        1              24          2        3
#
#   AttendanceRange
# 0               3
# 1               1
# 2               1
# 3               1
# 4               1
#
# [5 rows x 21 columns]

# %%
academic.to_csv('academic_info_and_bins.csv')

# %%
#select datapoints
stu = academic[['AgeRange', 'AttendanceRange', \
                 'Gender','Latino', 'Race', 'Grade', 'DeptCat', 'ProfCount']].copy()
stu.head()
# Out:
#   AgeRange AttendanceRange  Gender  Latino  Race  Grade  DeptCat ProfCount
# 0        3               3       2       1     5  77.13        1         3
# 1        3               1       2       1     5  63.00        3         2
# 2        3               1       2       1     5  76.00        2         1
# 3        3               1       2       1     5  87.00        2         3
# 4        3               1       2       1     5  92.39        1         2

# %%
academic.to_csv('binned_academic.csv')

# %%
stu['ProfCount'].value_counts()
# Out:
# 2    714
# 3    646
# 1    420
# Name: ProfCount, dtype: int64

# %%
stu.count()
# Out:
# AgeRange           1789
# AttendanceRange    1789
# Gender             1789
# Latino             1789
# Race               1789
# Grade              1789
# DeptCat            1789
# ProfCount          1780
# dtype: int64

# %%
money.head()
# Out:
#            ID   Grants   Loans  Federal  Institutional  Net_Total  YearBegin  \
# 0  2016000026  13490.5  5500.0   7333.0        10657.5    18934.5       2016
# 1   AC2802324  18065.5  7500.0  11183.0        14382.5    25487.5       2016
# 2  2016000037  11700.0  6500.0   6500.0        11700.0    18132.0       2016
# 3  2016000055   6000.0  5500.0   5500.0         6000.0    11444.0       2016
# 4   AR7969044  14745.5  6500.0   9383.0        11862.5    21177.5       2016
#
#    YearCat
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
money.head()
# Out:
#            ID   Grants   Loans  Federal  Institutional  Net_Total  YearBegin  \
# 0  2016000026  13490.5  5500.0   7333.0        10657.5    18934.5       2016
# 1   AC2802324  18065.5  7500.0  11183.0        14382.5    25487.5       2016
# 2  2016000037  11700.0  6500.0   6500.0        11700.0    18132.0       2016
# 3  2016000055   6000.0  5500.0   5500.0         6000.0    11444.0       2016
# 4   AR7969044  14745.5  6500.0   9383.0        11862.5    21177.5       2016
#
#    YearCat
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
money['YearCat'].value_counts()
# Out:
# 2    171
# 1    125
# 0     70
# Name: YearCat, dtype: int64

# %%
money['Loans'].value_counts(bins=3)
# Out:
# (329.742, 13120.333]      252
# (13120.333, 25872.667]     64
# (25872.667, 38625.0]       50
# Name: Loans, dtype: int64

# %%
money.head()
# Out:
#            ID   Grants   Loans  Federal  Institutional  Net_Total  YearBegin  \
# 0  2016000026  13490.5  5500.0   7333.0        10657.5    18934.5       2016
# 1   AC2802324  18065.5  7500.0  11183.0        14382.5    25487.5       2016
# 2  2016000037  11700.0  6500.0   6500.0        11700.0    18132.0       2016
# 3  2016000055   6000.0  5500.0   5500.0         6000.0    11444.0       2016
# 4   AR7969044  14745.5  6500.0   9383.0        11862.5    21177.5       2016
#
#    YearCat
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
#stu.Term_GPA.describe()

# %%
import matplotlib.pyplot as plt
plt.style.use(style='ggplot')
plt.rcParams['figure.figsize'] = (10, 6)

# %%
# # Skewness
# print("Skewness is: ", stu.Term_GPA.skew())
# plt.hist(stu.Term_GPA, color='orange')
# plt.show()

# %%
# merge_table = pd.merge(stu, dfM, on="ID", how="outer")
# merge_table

# %%
# target = np.log(stu.Term_GPA)
# print("Skewness is: ", target.skew())
# plt.hist(target, color='blue')
# plt.show()

# %%
plt.scatter(x=stu['Grade'], y=target)
plt.ylabel("Grade")
plt.xlabel("Attendance")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-758-18eeb9332911> in <module>
# ----> 1 plt.scatter(x=stu['Grade'], y=target)
#       2 plt.ylabel("Grade")
#       3 plt.xlabel("Attendance")
#       4 plt.show()
#
# TypeError: 'NoneType' object is not subscriptable

# %%
np.where(stu.values >= np.finfo(np.float64).max)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-759-fcd1ac0bae12> in <module>
# ----> 1 np.where(stu.values >= np.finfo(np.float64).max)
#
# AttributeError: 'NoneType' object has no attribute 'values'

# %%
stu.ProfCount.describe()
# Out:
# count     1780
# unique       3
# top          2
# freq       714
# Name: ProfCount, dtype: int64

# %%
print(stu['ProfCount'].value_counts())
# Out:
# 2    714
# 3    646
# 1    420
# Name: ProfCount, dtype: int64

# %%
#print(pd.get_dummies(stu['ProfCount']))

# %%
# from sklearn.preprocessing import Imputer
# # Create an imputer object that looks for 'Nan' values, then replaces them with the mean value of the feature by columns (axis=0)
# mean_imputer = Imputer(missing_values='NaN', strategy='mean', axis=0)

# # Train the imputor on the df dataset
# mean_imputer = mean_imputer.fit(stu)


# # Apply the imputer to the df dataset
# imputed_df = mean_imputer.transform(stu.values)

# %%
len(stu['ProfCount'].unique().tolist())
142
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-751-b2c190336995> in <module>
# ----> 1 len(stu['ProfCount'].unique().tolist())
#       2 142
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# Assign X (data) and y (target)

### BEGIN SOLUTION
X = stu[['AgeRange', 'AttendanceRange', 'Gender','Latino', 'Race', 'DeptCat', 'ProfCount']]
y = stu[["Grade"]].values.reshape(-1, 1)
print(X.shape, y.shape)
### END SOLUTION
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-743-d2227d5a3589> in <module>
#       2
#       3 ### BEGIN SOLUTION
# ----> 4 X = stu[['AgeRange', 'AttendanceRange', 'Gender','Latino', 'Race', 'DeptCat', 'ProfCount']]
#       5 y = stu[["Grade"]].values.reshape(-1, 1)
#       6 print(X.shape, y.shape)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# Split the data into training and testing

### BEGIN SOLUTION
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
### END SOLUTION

# %%
stu.dtypes
# Out:
# AgeRange           category
# AttendanceRange    category
# Gender                int64
# Latino                int64
# Race                  int64
# Grade               float64
# DeptCat                int8
# ProfCount          category
# dtype: object

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# Fitting our model with all of our features in X
model.fit(X, y)

score = model.score(X, y)
print(f"R2 Score: {score}")
# Out:
# R2 Score: 0.0721370531494091
